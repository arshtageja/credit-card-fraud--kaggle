# %%
import pandas as pd

# %%
data=pd.read_csv("../input/creditcardfraud/creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
col=data.columns
print(col)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data["Class"].plot()

# %%
data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data["Class"].value_counts().plot.bar()

# %%
import matplotlib.pyplot as plt
data=pd.DataFrame(data)

# %%
plt.scatter(data["Time"],data["Class"])

# %%
data.plot(x="Time",y="Class")

# %%
x=data.notnull()

# %%
x
# Out:
#         Time    V1    V2    V3    V4    V5    V6    V7    V8    V9  ...   V21  \
# 0       True  True  True  True  True  True  True  True  True  True  ...  True
# 1       True  True  True  True  True  True  True  True  True  True  ...  True
# 2       True  True  True  True  True  True  True  True  True  True  ...  True
# 3       True  True  True  True  True  True  True  True  True  True  ...  True
# 4       True  True  True  True  True  True  True  True  True  True  ...  True
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 284802  True  True  True  True  True  True  True  True  True  True  ...  True
# 284803  True  True  True  True  True  True  True  True  True  True  ...  True
# 284804  True  True  True  True  True  True  True  True  True  True  ...  True
# 284805  True  True  True  True  True  True  True  True  True  True  ...  True
# 284806  True  True  True  True  True  True  True  True  True  True  ...  True
#
# ...

# %%
x.columns.value_counts()
# Out:
# V1        1
# V15       1
# V19       1
# V13       1
# V10       1
# V16       1
# V28       1
# V5        1
# Amount    1
# V17       1
# V3        1
# V23       1
# V11       1
# V25       1
# V7        1
# V18       1
# Time      1
# V20       1
# Class     1
# V4        1
# V12       1
# V21       1
# V22       1
# V26       1
# V8        1
# V24       1
# V14       1
# V27       1
# V2        1
# V9        1
# V6        1
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
data1=data.sample(frac=0.1)

# %%
data1.shape
# Out:
# (28481, 31)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
target=data1["Class"]

# %%
data1=data1.drop(["Class"],axis=1)

# %%
data1.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 252594  155880.0 -0.674514  0.281555  0.758431  1.122540  0.607640 -0.465281
# 15436    26819.0 -2.197163 -1.058879  1.993564  0.727789  1.906719 -0.955103
# 245088  152602.0 -1.769102 -0.571667  0.685811 -0.628063  0.004222 -0.329594
# 198811  132662.0  0.072444 -0.275220  0.841308 -1.981832 -0.466242 -0.300955
# 211971  138655.0  1.961474 -0.059916 -1.604941  0.501263 -0.046760 -1.238458
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 252594  1.192957 -0.434342  0.668186  ...  0.242112  0.011836  0.800800
# 15436  -0.243529  0.360956 -0.524236  ...  0.407581  0.190102  0.014846
# 245088 -0.066065  0.681990  0.293276  ...  0.492586  0.358729  0.345879
# 198811 -0.214203  0.130454 -0.669264  ... -0.030546  0.494640  1.360107
# 211971  0.105576 -0.237367  1.114022  ... -0.178985 -0.231700 -0.480423
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data1, target, test_size=0.3)

# %%
df=clf.fit(X_train,y_train)

# %%
y_result=df.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_result)
# Out:
# array([[8530,    6],
#        [   5,    4]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_result)
# Out:
# 0.9987126974839087

# %%
from sklearn.ensemble import RandomForestClassifier
clf1 = RandomForestClassifier()

# %%
df1=clf1.fit(X_train,y_train)

# %%
result1=df1.predict(X_test)

# %%
accuracy_score(y_test,result1)
